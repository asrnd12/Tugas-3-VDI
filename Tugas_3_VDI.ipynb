# %% [markdown]
# Nama: Alvia Asrinda Br.Ginting
#
# NIM: 122450077
#
# Kelas: RB

# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime

# %%
data = pd.read_csv("/content/crime_dataset_india.csv")
data
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# ...

# %%
data.isnull().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# dtype: int64

# %% [markdown]
# ##1. Pie Chart

# %% [markdown]
# Tujuan:
# diagram pie chart berikut akan menampilkan distribusi presentase kejadian kejahatan di berbagai kota untuk membandingkan proporsi kejadian kejahatan antar kota dan memberikan gambaran umum tentang distribusi kejahatan di berbagai wilayah di India.
#
# User:
# Pemerintah, penegak hukum dan masyarakat umum
#
# Fungsi: Memyampaikan informasi tentang distribusi kejahatan secara visual dan ringkas untuk mengidentifikasi tren dan pola dalam data kejahatan serta untuk membuat keputusan terkait kebijakan keamanan di wilayah tersebut.

# %%
fig = px.pie(data, names='City', title='Distribusi Kejahatan berdasarkan Kota', hole=0.3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##2. Dot Plot

# %% [markdown]
# Tujuan:
# Dot plot berikut menunjukkan hubungan antara usia korban dengan berbagai jenis kejahatan yang dibedakan berdasarkan jenis kelamin dan membandingkan distribusi usia korban antar jenis kejahatan dan jenis kelamin.
#
# User:
# Pemerintah, penegak hukum, dan Masyarakat umum
#
# Fungsi:
# visualisasi ini memudahkan user untuk melihat distribusi data dan mengidentifikasi tren dengan cepat dan memahami informasi yang kompleks serta membantu dalam merumuskan hipotesis untuk penelitian lebih lanjut

# %%
fig = px.scatter(data, x='Victim Age', y='Crime Description',
                 color='Victim Gender',
                 title='Hubungan antara Usia Korban dan Jenis Kejahatan',
                 labels={'Victim Age': 'Usia Korban', 'Crime Description': 'Jenis Kejahatan'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
